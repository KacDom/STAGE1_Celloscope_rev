# %%
require(remotes)
system("apt install libgsl-dev", intern=TRUE)
install.packages("topicmodels")
remotes::install_github('JEFworks-Lab/STdeconvolve')
library(STdeconvolve)
# Out:
# [1] "Reading package lists..."
# [2] "Building dependency tree..."
# [3] "Reading state information..."
# [4] "libgsl-dev is already the newest version (2.4+dfsg-6)."
# [5] "The following package was automatically installed and is no longer required:"
# [6] "  libnvidia-common-460"
# [7] "Use 'apt autoremove' to remove it."
# [8] "0 upgraded, 0 newly installed, 0 to remove and 20 not upgraded."
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Skipping install of 'STdeconvolve' from a github remote, the SHA1 (2dbad6d7) has not changed since last install.
#   Use `force = TRUE` to force installation

# %%
my_working_dir = '/content'
setwd("/content")
dataset_zip = 'dense'
unzip(paste(dataset_zip, 'zip', sep='.'))

# %%
main_dir = paste("/content/", dataset_zip, sep="")
setwd(main_dir)
folders <- as.vector(list.dirs())
folders <- grep('setup', folders, value = TRUE)
folders = (folders[!grepl("checkpoints", folders)])
print(folders)
# Out:
#  [1] "./setup01" "./setup02" "./setup03" "./setup04" "./setup05" "./setup06"
#  [7] "./setup07" "./setup08" "./setup09" "./setup10" "./setup11" "./setup12"
# [13] "./setup13" "./setup14" "./setup15"

# %%
for (sub_dir in folders) {
    print(sub_dir)
    setwd(paste(main_dir, sub_dir, sep="/"))

    c_gs = as.matrix(read.csv("C_gs.csv", row.names = 1, header= TRUE))
    true_lambda<-read.csv("TRUE_lambda.csv", row.names = 1, header= TRUE)

    pos = data.frame(matrix(ncol = 0, nrow = ncol(c_gs)))
    rownames(pos) = colnames(c_gs)
    pos$x = c(1:nrow(pos))
    pos$y = c(1:nrow(pos))

    cd <- as.matrix(read.csv("C_gs.csv", row.names = 1, header= TRUE)) # df with genes as rownames and spot ids as colnames
    annot <- rep('tissue', ncol(cd)) # vector with names of cell types from 

    ## choose optimal number of cell-types
    ldas <- fitLDA(t(as.matrix(cd)), Ks = ncol(true_lambda), ncores=parallel::detectCores()) #ks - liczbe typow komorek

    ## get best model results
    optLDA <- optimalModel(models = ldas, opt = "min")
    ## extract deconvolved cell-type proportions (theta) and transcriptional profiles (beta)
    results <- getBetaTheta(optLDA, perc.filt = 0.)
    deconProp <- results$theta
    deconGexp <- results$beta
    write.csv(t(deconGexp), file=paste('marker_gene', "csv", sep="."))
    write.csv(deconProp, file=paste(sub_dir, "csv", sep="."))
}
# Out:
# [1] "./setup01"
# Loading required package: topicmodels
#
# Time to fit LDA models was 2.18 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.05 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup02"
# Time to fit LDA models was 2.02 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.05 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup03"
# Time to fit LDA models was 1.96 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup04"
# Time to fit LDA models was 2.18 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup05"
# Time to fit LDA models was 1.94 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.07 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup06"
# Time to fit LDA models was 2.4 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup07"
# Time to fit LDA models was 2.59 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup08"
# Time to fit LDA models was 2.56 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup09"
# Time to fit LDA models was 2.49 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup10"
# Time to fit LDA models was 2.5 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup11"
# Time to fit LDA models was 2.28 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup12"
# Time to fit LDA models was 2.24 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup13"
# Time to fit LDA models was 1.99 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup14"
# Time to fit LDA models was 1.98 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# [1] "./setup15"
# Time to fit LDA models was 2.21 mins
#
# Computing perplexity for each fitted model...
#
# Time to compute perplexities was 0.06 mins
#
# Getting predicted cell-types at low proportions...
#
# Time to compute cell-types at low proportions was 0 mins
#
# Plotting...
# plot without title
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# geom_path: Each group consists of only one observation. Do you need to adjust
# the group aesthetic?
#
# Filtering out cell-types in pixels that contribute less than 0 of the pixel proportion.
# plot without title
# plot without title

# %%
setwd("/content")
zip('dense.zip', 'dense')
